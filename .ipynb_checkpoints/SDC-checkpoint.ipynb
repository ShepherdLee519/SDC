# %%
import cirq
import qiskit
import random
import numpy as np

from cirq.contrib.svg import SVGCircuit
# Out:
# c:\users\lenovo\appdata\local\programs\python\python36\lib\site-packages\qiskit\__init__.py:67: DeprecationWarning: Using Qiskit with Python 3.6 is deprecated as of the 0.17.0 release. Support for running Qiskit with Python 3.6 will be removed in a future release.
#   "future release.", DeprecationWarning)

# %%
A1, A2, B, C = cirq.GridQubit.rect(1,4)

circuit = cirq.Circuit(
    cirq.H(A1), cirq.CNOT(control=A1, target=B),
    cirq.H(A2), cirq.CNOT(control=A2, target=C)
)


SVGCircuit(circuit)

# %%
def getCircuit(classical_bits):
    """
        getCircuit(circuit, ["01", "10"])
            => X(A1), Z(A2)
    """
    global circuit
    circuit_copy = circuit.copy()
    
    def operate(circuit, target, bits):
        if bits[0] == '1':
            circuit.append(cirq.Z(target))
        if bits[1] == '1':
            circuit.append(cirq.X(target))
        
        return circuit
    
    operate(circuit_copy, A1, classical_bits[0])
    operate(circuit_copy, A2, classical_bits[1])

    return circuit_copy

# %%
def buildU(p):
    matrixes = [
        cirq.unitary(cirq.I),cirq.unitary(cirq.X),
        cirq.unitary(cirq.Y),cirq.unitary(cirq.Z)
    ]
    
    U = np.zeros((4,4)).astype('complex128')
    pos = 0
    for i in range(4):
        for j in range(4):
            U += p[pos] * np.kron(matrixes[i], matrixes[j]).astype('complex128')
            pos += 1
            
    from qiskit.extensions import HamiltonianGate
    op = HamiltonianGate(U, 0.1)
    
    return op.to_matrix()

# %%
def generateRous(U, targets):
    bits = ["00", "01", "10", "11"]
    indexes = [0, 2] if targets == "AB" else [1, 3]
    rous = []
    
    from qiskit.quantum_info import partial_trace
    
    for i in range(4):
        for j in range(4):
            circuit = getCircuit([bits[i], bits[j]])
            circuit.append(cirq.ops.MatrixGate(U)(A1, A2))
            
            rous.append( partial_trace(cirq.unitary(circuit), indexes) )
    
    return rous

# %%
def sub_L(rou, sigma, loss_function):
    if loss_function == "F":
        # fidelity
        from cirq.qis import fidelity
        
        return fidelity(rou.data, sigma.data)
    
    elif loss_function == "D":
        # trace
        A = (rou - sigma)
        A = A.data
        tr = 0.5 * np.trace( (A.conj().T @ A) * 0.5 )
        
        return tr
    else:
        return 0

# %%
def L(bits, p, loss_function):
    U = buildU(p)
    rous_AB = generateRous(U, "AB")
    rous_AC = generateRous(U, "AC")
    
#     size = len(p)
    rou = rous_AB.pop(6)
    sigma = rous_AC.pop(6)
    
    loss = 0
    for r in rous_AB:
        loss += sub_L(rou, r, loss_function)
    for s in rous_AC:
        loss += sub_L(sigma, s, loss_function)
        
    loss = 0.5 * (1 / ((16 * 2 - 16)/2)) * loss
    if loss_function == "F":
        loss *= -1
    
    return loss

# %%
def GradientCalculator(bits, p, epsilon, loss_function):
    derivates = np.zeros(len(p))
    
    for i, param in enumerate(p):
        p[i] += epsilon
        l_pe = L(bits, p, loss_function)
        p[i] -= epsilon
        l_p = L(bits, p, loss_function)
        
        derivates[i] = (l_pe - l_p) / epsilon
        
#     print(derivates)
    return derivates

# %%
params = []

def SDCLearner(n, *, loss_function="D", epoch=1000, epsilon=0.01):
    # 1. initialize the parameters with uniformly random nunbers
    size = 2 ** (2 * n)
    bits = ["01", "10"]
    p = np.random.uniform(-1, 1, size)
    
    # Adam parameters:
    momentum, s = 0, 0
    alpha = 0.001
    belta1 = 0.9; belta2 = 0.999
    e = 1e-8
    
    global params
    
    t = 0
    while t < epoch:
        # repeat
        t += 1
        grad = GradientCalculator(bits, p, epsilon, loss_function)
        
        momentum = belta1 * momentum - (1 - belta1) * grad
        s = belta2 * s + (1 - belta2) * (grad * grad)
        m_ = momentum / (1 - belta1)
        s_ = s / (1 - belta2)

        p = p - alpha * (m_ / ( (s_ + e) ** 0.5 ))
        print('epoch: [{}/{}] - end.'.format(t, epoch))
    
    params = p

SDCLearner(2)
# Out:
# c:\users\lenovo\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:10: ComplexWarning: Casting complex values to real discards the imaginary part
#   # Remove the CWD from sys.path while we load stuff.
# epoch: [1/1000] - end.
# epoch: [2/1000] - end.
# epoch: [3/1000] - end.
# epoch: [4/1000] - end.
# epoch: [5/1000] - end.
# epoch: [6/1000] - end.
# epoch: [7/1000] - end.
# epoch: [8/1000] - end.
# epoch: [9/1000] - end.
# epoch: [10/1000] - end.
# epoch: [11/1000] - end.
# epoch: [12/1000] - end.
# epoch: [13/1000] - end.
# epoch: [14/1000] - end.
# epoch: [15/1000] - end.
# epoch: [16/1000] - end.
# epoch: [17/1000] - end.
# epoch: [18/1000] - end.
# epoch: [19/1000] - end.
# epoch: [20/1000] - end.
# epoch: [21/1000] - end.
# epoch: [22/1000] - end.
# epoch: [23/1000] - end.
# epoch: [24/1000] - end.
# epoch: [25/1000] - end.
# epoch: [26/1000] - end.
# epoch: [27/1000] - end.
# epoch: [28/1000] - end.
# epoch: [29/1000] - end.
# epoch: [30/1000] - end.
# epoch: [31/1000] - end.
# epoch: [32/1000] - end.
# epoch: [33/1000] - end.
# epoch: [34/1000] - end.
# epoch: [35/1000] - end.
# epoch: [36/1000] - end.
# epoch: [37/1000] - end.
# epoch: [38/1000] - end.
# epoch: [39/1000] - end.
# epoch: [40/1000] - end.
# epoch: [41/1000] - end.
# epoch: [42/1000] - end.
# epoch: [43/1000] - end.
# epoch: [44/1000] - end.
# epoch: [45/1000] - end.
# epoch: [46/1000] - end.
# epoch: [47/1000] - end.
# epoch: [48/1000] - end.
# epoch: [49/1000] - end.
# epoch: [50/1000] - end.
# epoch: [51/1000] - end.
# epoch: [52/1000] - end.
# epoch: [53/1000] - end.
# epoch: [54/1000] - end.
# epoch: [55/1000] - end.
# epoch: [56/1000] - end.
# epoch: [57/1000] - end.
# epoch: [58/1000] - end.
# epoch: [59/1000] - end.
# epoch: [60/1000] - end.
# epoch: [61/1000] - end.
# epoch: [62/1000] - end.
# epoch: [63/1000] - end.
# epoch: [64/1000] - end.
# epoch: [65/1000] - end.
# epoch: [66/1000] - end.
# epoch: [67/1000] - end.
# epoch: [68/1000] - end.
# epoch: [69/1000] - end.
# epoch: [70/1000] - end.
# epoch: [71/1000] - end.
# epoch: [72/1000] - end.
# epoch: [73/1000] - end.
# epoch: [74/1000] - end.
# epoch: [75/1000] - end.
# epoch: [76/1000] - end.
# epoch: [77/1000] - end.
# epoch: [78/1000] - end.
# epoch: [79/1000] - end.
# epoch: [80/1000] - end.
# epoch: [81/1000] - end.
# epoch: [82/1000] - end.
# epoch: [83/1000] - end.
# epoch: [84/1000] - end.
# epoch: [85/1000] - end.
# epoch: [86/1000] - end.
# epoch: [87/1000] - end.
# epoch: [88/1000] - end.
# epoch: [89/1000] - end.
# epoch: [90/1000] - end.
# epoch: [91/1000] - end.
# epoch: [92/1000] - end.
# epoch: [93/1000] - end.
# epoch: [94/1000] - end.
# epoch: [95/1000] - end.
# epoch: [96/1000] - end.
# epoch: [97/1000] - end.
# epoch: [98/1000] - end.
# epoch: [99/1000] - end.
# epoch: [100/1000] - end.
# epoch: [101/1000] - end.
# epoch: [102/1000] - end.
# epoch: [103/1000] - end.
# epoch: [104/1000] - end.
# epoch: [105/1000] - end.
# epoch: [106/1000] - end.
# epoch: [107/1000] - end.
# epoch: [108/1000] - end.
# epoch: [109/1000] - end.
# epoch: [110/1000] - end.
# epoch: [111/1000] - end.
# epoch: [112/1000] - end.
# epoch: [113/1000] - end.
# epoch: [114/1000] - end.
# epoch: [115/1000] - end.
# epoch: [116/1000] - end.
# epoch: [117/1000] - end.
# epoch: [118/1000] - end.
# epoch: [119/1000] - end.
# epoch: [120/1000] - end.
# epoch: [121/1000] - end.
# epoch: [122/1000] - end.
# epoch: [123/1000] - end.
# epoch: [124/1000] - end.
# epoch: [125/1000] - end.
# epoch: [126/1000] - end.
# epoch: [127/1000] - end.
# epoch: [128/1000] - end.
# epoch: [129/1000] - end.
# epoch: [130/1000] - end.
# epoch: [131/1000] - end.
# epoch: [132/1000] - end.
# epoch: [133/1000] - end.
# epoch: [134/1000] - end.
# epoch: [135/1000] - end.
# epoch: [136/1000] - end.
# epoch: [137/1000] - end.
# epoch: [138/1000] - end.
# epoch: [139/1000] - end.
# epoch: [140/1000] - end.
# epoch: [141/1000] - end.
# epoch: [142/1000] - end.
# epoch: [143/1000] - end.
# epoch: [144/1000] - end.
# epoch: [145/1000] - end.
# epoch: [146/1000] - end.
# epoch: [147/1000] - end.
# epoch: [148/1000] - end.
# epoch: [149/1000] - end.
# epoch: [150/1000] - end.
# epoch: [151/1000] - end.
# epoch: [152/1000] - end.
# epoch: [153/1000] - end.
# epoch: [154/1000] - end.
# epoch: [155/1000] - end.
# epoch: [156/1000] - end.
# epoch: [157/1000] - end.
# epoch: [158/1000] - end.
# epoch: [159/1000] - end.
# epoch: [160/1000] - end.
# epoch: [161/1000] - end.
# epoch: [162/1000] - end.
# epoch: [163/1000] - end.
# epoch: [164/1000] - end.
# epoch: [165/1000] - end.
# epoch: [166/1000] - end.
# epoch: [167/1000] - end.
# epoch: [168/1000] - end.
# epoch: [169/1000] - end.
# epoch: [170/1000] - end.
# epoch: [171/1000] - end.
# epoch: [172/1000] - end.
# epoch: [173/1000] - end.
# epoch: [174/1000] - end.
# epoch: [175/1000] - end.
# epoch: [176/1000] - end.
# epoch: [177/1000] - end.
# epoch: [178/1000] - end.
# epoch: [179/1000] - end.
# epoch: [180/1000] - end.
# epoch: [181/1000] - end.
# epoch: [182/1000] - end.
# epoch: [183/1000] - end.
# epoch: [184/1000] - end.
# epoch: [185/1000] - end.
# epoch: [186/1000] - end.
# epoch: [187/1000] - end.
# epoch: [188/1000] - end.
# epoch: [189/1000] - end.
# epoch: [190/1000] - end.
# epoch: [191/1000] - end.
# epoch: [192/1000] - end.
# epoch: [193/1000] - end.
# epoch: [194/1000] - end.
# epoch: [195/1000] - end.
# epoch: [196/1000] - end.
# epoch: [197/1000] - end.
# epoch: [198/1000] - end.
# epoch: [199/1000] - end.
# epoch: [200/1000] - end.
# epoch: [201/1000] - end.
# epoch: [202/1000] - end.
# epoch: [203/1000] - end.
# epoch: [204/1000] - end.
# epoch: [205/1000] - end.
# epoch: [206/1000] - end.
# epoch: [207/1000] - end.
# epoch: [208/1000] - end.
# epoch: [209/1000] - end.
# epoch: [210/1000] - end.
# epoch: [211/1000] - end.
# epoch: [212/1000] - end.
# epoch: [213/1000] - end.
# epoch: [214/1000] - end.
# epoch: [215/1000] - end.
# epoch: [216/1000] - end.
# epoch: [217/1000] - end.
# epoch: [218/1000] - end.
# epoch: [219/1000] - end.
# epoch: [220/1000] - end.
# epoch: [221/1000] - end.
# epoch: [222/1000] - end.
# epoch: [223/1000] - end.
# epoch: [224/1000] - end.
# epoch: [225/1000] - end.
# epoch: [226/1000] - end.
# epoch: [227/1000] - end.
# epoch: [228/1000] - end.
# epoch: [229/1000] - end.
# epoch: [230/1000] - end.
# epoch: [231/1000] - end.
# epoch: [232/1000] - end.
# epoch: [233/1000] - end.
# epoch: [234/1000] - end.
# epoch: [235/1000] - end.
# epoch: [236/1000] - end.
# epoch: [237/1000] - end.
# epoch: [238/1000] - end.
# epoch: [239/1000] - end.
# epoch: [240/1000] - end.
# epoch: [241/1000] - end.
# epoch: [242/1000] - end.
# epoch: [243/1000] - end.
# epoch: [244/1000] - end.
# epoch: [245/1000] - end.
# epoch: [246/1000] - end.
# epoch: [247/1000] - end.
# epoch: [248/1000] - end.
# epoch: [249/1000] - end.
# epoch: [250/1000] - end.
# epoch: [251/1000] - end.
# epoch: [252/1000] - end.
# epoch: [253/1000] - end.
# epoch: [254/1000] - end.
# epoch: [255/1000] - end.
# epoch: [256/1000] - end.
# epoch: [257/1000] - end.
# epoch: [258/1000] - end.
# epoch: [259/1000] - end.
# epoch: [260/1000] - end.
# epoch: [261/1000] - end.
# epoch: [262/1000] - end.

# %%
params
# Out:
# array([ 0.57199973, -0.66686979,  0.09302178,  1.02064739, -1.30309107,
#        -0.03772516,  0.9005324 , -0.95523202, -1.03953863,  0.67178943,
#         1.05932677, -1.30362216,  1.51618357,  0.29023613,  0.59047519,
#        -0.52782317])

# %%
buildU(params)
# Out:
# array([[ 0.89482654-0.24219613j, -0.05560151+0.03335826j,
#          0.25944395+0.17390076j, -0.15542094+0.12130079j],
#        [ 0.08031575+0.03640876j,  0.97792819-0.15806532j,
#          0.01555944-0.09297877j, -0.03062733+0.0327171j ],
#        [-0.19011412+0.25870149j, -0.03210051-0.1075383j ,
#          0.93529476-0.05251632j,  0.0464174 +0.0681645j ],
#        [ 0.14677219+0.0907654j ,  0.02367329+0.03622364j,
#         -0.04850026+0.11693452j,  0.94445755+0.24560328j]])
